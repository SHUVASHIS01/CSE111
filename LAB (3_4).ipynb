# %%
#TASk1
class Patient:
  def __init__(self,name,age,weight,height):
    self.name=name
    self.age=age
    self.weight=weight
    self.height=height
  def printDetails(self):
    print(f'Name: {self.name}\nAge: {self.age}\nWeight: {self.weight}\nHeight: {self.height}')
    print(f'BMI: {self.weight/((self.height/100)**2)}')
p1 = Patient("A", 55, 63.0, 158.0)
p1.printDetails()
print("====================")
p2 = Patient("B", 53, 61.0, 149.0)
p2.printDetails()
# Out:
# Name: A
# Age: 55
# Weight: 63.0
# Height: 158.0
# BMI: 25.236340330075304
# ...
# Name: B
# Age: 53
# Weight: 61.0
# Height: 149.0
# BMI: 27.476239809017613

# %%
#task2
class Shape:
  def __init__ (self,name,a,b):
    self.name=name
    self.a=a
    self.b=b
  def area(self):
    if self.name=='Triangle' or self.name=="Rhombus":
      print(f'Area: {.5*self.a*self.b}')
    elif self.name=='Square' or self.name=='Rectangle':
      print(f'Area: {self.a*self.b}')
    else:
      print('Shape unknown')


triangle = Shape("Triangle",10,25)
triangle.area()
print("==========================")
square = Shape("Square",10,10)
square.area()
print("==========================")
rhombus = Shape("Rhombus",18,25)
rhombus.area()
print("==========================")
rectangle = Shape("Rectangle",15,30)
rectangle.area()
print("==========================")
trapezium = Shape("Trapezium",15,30)
trapezium.area()
# Out:
# Area: 125.0
# ...
# Area: 100
# ...
# Area: 225.0
# ...
# Area: 450
# ...
# Shape unknown

# %%
#task3
class Calculator:
  def __init__ (self):
    print('Calculator is ready!')
  def calculate(self,a,b,c):
    self.a=a
    self.b=b
    self.c=c
    if c=='+':
      return a+b
    elif c=='-':
      return a-b
    elif c=='*':
      return a*b
    elif c=='/':
      return a/b
  def showCalculation(self):
    print(f'{self.a}{self.c}{self.b}={val}')
c1 = Calculator()
print("==================")
val = c1.calculate(10, 20, '+')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 10, '-')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 5, '*')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 16, '/')
print("Returned value:", val)
c1.showCalculation()
# Out:
# Calculator is ready!
# ...
# Returned value: 30
# 10+20=30
# ...
# Returned value: 20
# 30-10=20
# ...
# Returned value: 100
# 20*5=100
# ...
# Returned value: 6.25
# 100/16=6.25

# %%
#task4
class Programmer:
  def __init__(self,name,language,exp):
    self.name=name
    self.language=language
    self.exp=exp
    print('Horray! A new programmer is born')
  def addExp(self,a):
    print(f'Updating experience of {self.name}')
    self.exp+=a
  def printDetails(self):
    print(f'Name:{self.name}\nLanguage:{self.language}\nExperience:{self.exp} years.')
p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name:Ethen Hunt
# Language:Java
# Experience:10 years.
# --------------------------
# Horray! A new programmer is born
# Name:James Bond
# Language:C++
# Experience:7 years.
# --------------------------
# Horray! A new programmer is born
# Name:Jon Snow
# Language:Python
# Experience:4 years.
# Updating experience of Jon Snow
# Name:Jon Snow
# Language:Python
# Experience:9 years.

# %%
#task5
class UberEats:
  def __init__ (self,name,nmbr,location):
    self.name=name
    self.nmbr=nmbr
    self.location=location
    print(f'{self.name}, welcome to UberEats!')
  def add_items(self,brgr,coc,bprice,cprice):
    self.brgr=brgr
    self.coc=coc
    self.bprice=bprice
    self.cprice=cprice
  def print_order_detail(self):
    d={}
    d.update({self.brgr:self.bprice,self.coc:self.cprice})
    return f'User details: {self.name}, Phone:{self.nmbr}, Address:{self.location}\nOrders:{d}\nTotal Paid Amount:{self.bprice+self.cprice}'

    
order1 = UberEats("Shakib", "01719658xxx", "Mohakhali")
print("=========================")
order1.add_items("Burger", "Coca Cola", 220, 50)
print("=========================")
print(order1.print_order_detail())
print("=========================")
order2 = UberEats ("Siam", "01719659xxx", "Uttara")
print("=========================")
order2.add_items("Pineapple", "Dairy Milk", 80, 70)
print("=========================")
print(order2.print_order_detail())
# Out:
# Shakib, welcome to UberEats!
# ...
# User details: Shakib, Phone:01719658xxx, Address:Mohakhali
# Orders:{'Burger': 220, 'Coca Cola': 50}
# Total Paid Amount:270
# ...
# Siam, welcome to UberEats!
# ...
# User details: Siam, Phone:01719659xxx, Address:Uttara
# Orders:{'Pineapple': 80, 'Dairy Milk': 70}
# Total Paid Amount:150

# %%
#task6
class Customer:
  def __init__(self,name):
    self.name=name
  def greet(self,a=None):
    if a==None:
      print(f'Hello!')
    else:
      print(f'Hello {a}!')
  def purchase(self,*args):
      print(f'{self.name}, you purchased {len(args)} items')
      for i in args:
        print(i)

customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchased 3 items
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David, you purchased 1 items
# orange juice

# %%
#task7
class Cat:
  def __init__(self,a='White',b='sitting'):
    self.a=a
    self.b=b
  def printCat(self):
    print(f'{self.a} cat is {self.b}')
  def changeColor(self,clr):
    self.a=clr


c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#task8
class Student:
  def __init__ (self,a,b,c='CSE'):
    self.a=a
    self.b=b
    self.c=c
  def dailyEffort(self,efrt):
    self.efrt=efrt
  def printDetails(self):
    print(f'Name: {self.a}\nID: {self.b}\nDepartment:{self.c}\nDaily Effort: {self.efrt} hour(s)')
    if self.efrt<=2:
      print('Suggestion: Should give more effort!')
    elif self.efrt<=4:
      print('Suggestion: Keep up the good work!')
    else:
      print('Excellent! Now motivate others.')
harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()	
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department:CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department:BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department:Ninja
# Daily Effort: 6 hour(s)
# Excellent! Now motivate others.

# %%
#task9
class Batsman:
  def __init__(self,*args):
    if len(args)==2:
      self.run=args[0]
      self.ball=args[1]
      self.name='New Batsman'
    else:
      self.name=args[0]
      self.run=args[1]
      self.ball=args[2]
  def printCareerStatistics(self):
    print(f'Name: {self.name}\nRuns Scored: {self.run} , Balls Faced: {self.ball}')
  def battingStrikeRate(self):
    return (self.run/self.ball)*100
  def setName(self,a):
    self.name=a
b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101 , Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678 , Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101 , Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#task10
class Author:
  def __init__ (self,*names):
    self.book=[]
    if len(names)==0:
      self.name='Default'
    elif len(names)==1:
      self.name=names[0]
    else:
      self.name=names[0]
      for j in range(1,len(names)):
        self.book.append(names[j])
  def addBooks(self,*args):
    self.book=args
  def changeName(self,a):
    self.name=a
  def printDetails(self):
    print(f'Author Name: {self.name}\n------\nList of Books:')
    for i in self.book:
      print (i)
auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# ------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name: Mario Puzo
# ------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name: Paolo Coelho
# ------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#task11
class TaxiLagbe:
  def __init__(self,tnmbr,area):
    self.tnmbr=tnmbr
    self.area=area
    self.name=''
    self.count=0
    self.tk=0
  def addPassenger(self,*args):
    if self.count!=4:
      for i in args:
        m=i.split('_')
        self.tk+=int(m[1])
        self.count+=1
        self.name+=m[0]+', '
        print(f'Dear {m[0]}! Welcome to TaxiLagbe')
    else:
        print('Taxi Full! No more passengers can be added.')
  def printDetails(self):
      print(f'Trip info for Taxi number: {self.tnmbr}')
      print(f'This taxi can cover only {self.area} area. ')
      print(f'Total passengers: {self.count}')
      print(f'Passenger lists:{self.name[:-2:]}')
      print(f'Total collected fare:{self.tk}')
taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200')
taxi1.addPassenger('Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115')
taxi2.addPassenger('Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe
# Dear Wood! Welcome to TaxiLagbe
# Dear Matt! Welcome to TaxiLagbe
# Dear Wilson! Welcome to TaxiLagbe
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:Walker, Wood, Matt, Wilson
# Total collected fare:505
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:Walker, Wood, Matt, Wilson
# Total collected fare:505
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe
# Dear Parker! Welcome to TaxiLagbe
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers: 2
# Passenger lists:Ronald, Parker
# Total collected fare:330

# %%
#task12
class Account:
  def __init__(self,*args):
    if len(args)==0:
      self.name='Default Account'
      self.balance=0.0
    elif len(args)==1:
      self.name=args[0]
      self.balance=0.0
    else:
      self.name=args[0]
      self.balance=float(args[1])
  def details(self):
    return f'{self.name}\n{self.balance}'
  def withdraw(self,wtdr):
    if self.balance-wtdr<=3070:
      print(f'Sorry, Withdraw unsuccessful! The account \nbalance after deducting withdraw amount is \nequal to or less than minimum.')
    else:
      print(f'Withdraw successful! New balance is:\n{self.balance-wtdr}')





a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930)
print("------------------------")
a2.withdraw(600)
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400.0
# ------------------------
# Sorry, Withdraw unsuccessful! The account
# balance after deducting withdraw amount is
# equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account
# balance after deducting withdraw amount is
# equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is:
# 3071.0

# %%
#task13
class StudentDatabase:
  def __init__(self,name,id,grades=None):
    self.name=name
    self.id=id
    self.grades={}
  def calculateGPA(self,courses,session):
    self.courses=courses
    self.session=session
    self.l=[]
    self.s=0
    self.d={}
    for i in courses:
      i=i.split(': ')
      self.l.append(i[0])
      self.s+=float(i[1])
      self.avg=(self.s)/(len(self.l))
    self.d[tuple(self.l)]=self.avg
    self.grades[self.session]=self.d
  def printDetails(self):
    print(f'Name:{self.name}\nID:{self.id}')
    for j in self.grades:
      print(f'Courses taken in {j}:')
      for k,v in self.grades[j].items():
        for x in k:
          print(x)
        print('GPA:','%.2f' % v)
s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('------------------------------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
print('------------------------------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('------------------------------------------------------')
s2.printDetails()
# Out:
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ------------------------------------------------------
# Name:Pietro
# ID:10101222
# Courses taken in Summer2020:
# CSE230
# CSE220
# MAT110
# GPA: 4.00
# Courses taken in Summer2021:
# CSE250
# CSE330
# GPA: 3.85
# ------------------------------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8000000000000003}}
# ------------------------------------------------------
# Name:Wanda
# ID:10103332
# Courses taken in Summer2022:
# CSE111
# CSE260
# ENG101
# GPA: 3.80

# %%
class Test3:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):
        x, y = 2, 3
        msg = [0]
        msg[0] = 3
        y = self.y + msg[0]
        self.methodB(msg, msg[0])
        x = self.y + msg[0]
        self.sum = x + y + msg[0]
        print(x, y, self.sum)
    def methodB(self, mg2, mg1):
        x = 0
        self.y = self.y + mg2[0]
        x = x + 33 + mg1
        self.sum = self.sum + x + self.y
        mg2[0] = self.y + mg1
        mg1 = mg1 + x + 2
        print(x, self.y, self.sum)

t3 = Test3()
t3.methodA()
t3.methodA()
t3.methodA()
t3.methodA()
# Out:
# 36 3 39
# 9 3 18
# 36 6 60
# 15 6 30
# 36 9 75
# 21 9 42
# 36 12 90
# 27 12 54

# %%
class Test5:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):    
        x = 0
        z = 0
        while (z < 5):
            self.y = self.y + self.sum
            x = self.y + 1
            print(x, self.y, self.sum)
            self.sum = self.sum + self.methodB(x, self.y)
            z += 1
    def methodB(self, m, n):
        x = 0
        sum = 0
        self.y = self.y + m
        x = n - 4
        sum = sum + self.y
        print(x, self.y, sum)
        return self.sum

t5 = Test5()
t5.methodA()
# Out:
# 1 0 0
# -4 1 1
# 2 1 0
# -3 3 3
# 4 3 0
# -1 7 7
# 8 7 0
# 3 15 15
# 16 15 0
# 11 31 31

# %% [markdown]
# ***UNGRADED***

# %%
#task20
class Student:
  def __init__ (self,name=None,sub=None):
    self.name=name
    self.sub=sub
    if self.name == None and self.sub==None:
      print(f'Student name and department need to be set')
    elif self.sub==None:
      print(f'Department for {self.name} needs to be set')
    else:
      print(f'{self.name} is from {self.sub} department')
  def update_name(self,a):
      self.name=a
  def update_department(self,b):
      self.sub=b
  def enroll(self,*args):
      self.s=''
      self.count=len(args)
      self.args=args
      for i in self.args:
        self.s+=i+', '
  def printDetail(self):
      print(f'Name:{self.name}\nDepartment:{self.sub}\n{self.name} enrolled {self.count} course(s):\n{self.s[:-2:]}')
s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ###########################
# Name:Bob
# Department:CSE
# Bob enrolled 3 course(s):
# CSE110, MAT110, ENG091
# ...
# Name:Carol
# Department:BBA
# Carol enrolled 1 course(s):
# BUS101
# ...
# Name:Jon
# Department:EEE
# Jon enrolled 2 course(s):
# MAT110, PHY111

# %%
#task21
class Student:
  def __init__ (self,name,id,sub):
    self.name=name
    self.id=id
    self.sub=sub
  def details(self):
    return f'Name:{self.name}\nID:{self.id}\nDepartment:{self.sub}'
  def advise(self,*args):
    s=''
    for i in args:
      s+=i+', '
    if len(args)>=3 and len(args)<=4:
      print(f'{self.name}, you have taken {len(args)*3.0}')
      print(f'List of courses: {s[:-2:]}')
      print('Status: Ok')
    elif len(args)<3:
      print(f'{self.name}, you have taken {len(args)*3.0} credits')
      print(f'List of courses: {s[:-2:]}')
      print(f'Status: you have to take at least {3-len(args)} more course.')
    elif len(args)>4:
      print(f'{self.name}, you have taken {len(args)*3.0}')
      print(f'List of courses: {s[:-2:]}')
      print(f'Status: you have to drop at least {len(args)-4} course.')
s1 = Student('Alice','20103012','CSE')
s2 = Student('Bob', '18301254','EEE')
s3 = Student('Carol', '17101238','CSE')
print('##########################')
print(s1.details())
print('##########################')
print(s2.details())
print('##########################')
s1.advise('CSE110', 'MAT110', 'PHY111')
print('##########################')
s2.advise('BUS101', 'MAT120')
print('##########################')
s3.advise('MAT110', 'PHY111', 'ENG102',
'CSE111', 'CSE230')
# Out:
# ##########################
# Name:Alice
# ID:20103012
# Department:CSE
# ##########################
# Name:Bob
# ID:18301254
# Department:EEE
# ##########################
# Alice, you have taken 9.0
# List of courses: CSE110, MAT110, PHY111
# Status: Ok
# ##########################
# Bob, you have taken 6.0 credits
# List of courses: BUS101, MAT120
# Status: you have to take at least 1 more course.
# ##########################
# Carol, you have taken 15.0
# List of courses: MAT110, PHY111, ENG102, CSE111, CSE230
# Status: you have to drop at least 1 course.

# %%
#task22
class Hotel:
  def __init__ (self,a):
    self.c=0
    self.d={}
    self.s={}
    self.sum=0
  def addStuff(self,name,age,phn='000'):
    l=[]
    self.c+=1
    self.name=name
    self.age=age
    self.phn=phn
    print(f'Staff With {self.c} is added')
    l.append(self.name)
    l.append(self.age)
    l.append(self.phn)
    self.d[self.c]=l
  def getStuffById(self,a):
    c=a
    self.a=a
    return f'staff ID: {self.a}\nName: {self.name}\nAge: {self.age}\nphone no.:{self.phn}'
  def addGuest(self,name,age,phn):
    k=[]
    self.sum+=1
    self.name=name
    self.age=age
    self.phn=phn
    print(f'Guest With {self.sum} is added')
    k.append(self.name)
    k.append(self.age)
    k.append(self.phn)
    self.s[self.sum]=k
  def getGuestById(self,a):
    sum=a
    self.a=a
    return f'Guest ID: {self.a}\nName: {self.name}\nAge: {self.age}\nphone no.:{self.phn}'
  def allStaffs(self):
    for k,v in self.d.items():
      print(f'all staffs:\nNumber of staff:{self.c}\nstaff id: {k} Name: {v[0]} Age:{v[1]} phone: {v[2]}')
  def allGuest(self):
    print(f'all guests:\nNumber of guest:{self.sum}')
    for k,v in self.s.items():
      print(f'Guest id: {k} Name:{v[0]} Age:{v[1]} phone: {v[2]}')
h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest('Carol',35,'123')
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, '431')
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# Staff With 1 is added
# ...
# staff ID: 1
# Name: Adam
# Age: 26
# phone no.:000
# ...
# Guest With 1 is added
# ...
# Guest ID: 1
# Name: Carol
# Age: 35
# phone no.:123
# ...
# Guest With 2 is added
# ...
# Guest ID: 2
# Name: Diana
# Age: 32
# phone no.:431
# ...
# all staffs:
# Number of staff:1
# staff id: 1 Name: Adam Age:26 phone: 000
# ...
# all guests:
# Number of guest:2
# Guest id: 1 Name:Carol Age:35 phone: 123
# Guest id: 2 Name:Diana Age:32 phone: 431

# %%
class Student:
  def __init__(self,*args):
    if len(args) == 2:
      self.name = args[0]
      self.id = args[1]
    elif len(args) == 3:
      self.name = args[0]
      self.id = args[1]
      self.subj = args[2]
    
  def dailyEffort(self,dailyeffort):
    self.dailyeffort = dailyeffort
    if self.dailyeffort <= 2:
      self.sugg = "Should give more effort"
  
    elif self.dailyeffort <=4:
      self.sugg = "Keep up the good work!" 

    else:
      self.sugg = "Keep up the good work!"
    
  
  def printDetails(self):
   print(f"Name:{self.name}\nID:{self.id}\nDepartment:{self.subj}n\Daily Efforts: {self.time} hour(s)\n{self.sugg}")

harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()	
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-343a44769618> in <module>
#      26 harry = Student('Harry Potter', 123)
#      27 harry.dailyEffort(3)
# ---> 28 harry.printDetails()
#      29 print('========================')
#      30 john = Student("John Wick", 456, "BBA")
#
# <ipython-input-1-343a44769618> in printDetails(self)
#      22
#      23   def printDetails(self):
# ---> 24    print(f"Name:{self.name}\nID:{self.id}\nDepartment:{self.subj}n\Daily Efforts: {self.time} hour(s)\n{self.sugg}")
#      25
#      26 harry = Student('Harry Potter', 123)
#
# AttributeError: 'Student' object has no attribute 'subj'

# %%
class Student:
  def __init__ (self,a,b,c='CSE'):
    self.a=a
    self.b=b
    self.c=c
  def dailyEffort(self,efrt):
    self.efrt=efrt
  def printDetails(self):
    print(f'Name: {self.a}\nID: {self.b}\nDepartment:{self.c}\nDaily Effort: {self.efrt} hour(s)')
    if self.efrt<=2:
      print('Suggestion: Should give more effort!')
    elif self.efrt<=4:
      print('Suggestion: Keep up the good work!')
    else:
      print('Excellent! Now motivate others.')
harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()	
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department:CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department:BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department:Ninja
# Daily Effort: 6 hour(s)
# Excellent! Now motivate others.

# %%
#Task23
class Author:
  def __init__ (self,a=None):
    self.name=a
    self.d={}
    self.c=0
  def setName(self,a):
    self.name=a
  def addBook(self,bnm,btype):
    self.btype=bnm
    self.dbtype=btype
    if btype in self.d:
      self.d[btype].append(bnm)
    else:
      self.d[btype]=[bnm]

    if self.name==None:
      print('A book can not be added without author name')
    else:
      self.c+=1
  def printDetail(self):
    print(f'Number of Book(s):{self.c}\nAuthor Name:{self.name}')
    for k,v in self.d.items():
      print(f'{k}:{v}')
a1 = Author()
print("=================================")
a1.addBook('Ice', 'Science Fiction')
print("=================================")
a1.setName('Anna Kavan')
a1.addBook('Ice', 'Science Fiction')
a1.printDetail()
print("=================================")
a2 = Author('Humayun Ahmed')
a2.addBook('Onnobhubon', 'Science Fiction')
a2.addBook('Megher Upor Bari', 'Horror')
print("=================================")
a2.printDetail()
a2.addBook('Ireena', 'Science Fiction')
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Book(s):1
# Author Name:Anna Kavan
# Science Fiction:['Ice', 'Ice']
# ...
# Number of Book(s):2
# Author Name:Humayun Ahmed
# Science Fiction:['Onnobhubon']
# Horror:['Megher Upor Bari']
# ...
# Number of Book(s):3
# Author Name:Humayun Ahmed
# Science Fiction:['Onnobhubon', 'Ireena']
# Horror:['Megher Upor Bari']
# ...

# %%
#Task24
class Hospital:
  def __init__ (self,Hname):
    self.dctr=0
    self.rugi=0
    self.d={}
    self.p={}
    self.Hname=Hname
  def addDoctor(self,obj):
    self.obj=obj
    self.dctr+=1
    self.d[self.obj.did]=[self.obj.dname, self.obj.dtype]
  def getDoctorByID(self,id):
    if id==self.obj.did:
      return f'Doctors ID: {self.obj.did}\nName: {self.obj.dname}\nSpeciality: {self.obj.dtype}'
  def addPatient(self,pobj):
    self.pobj=pobj
    self.rugi+=1
    self.p[self.pobj.pid]=[self.pobj.pname, self.pobj.page, self.pobj.pphn]
  def getPatientByID(self,rid):
    if rid==self.pobj.pid:
      return f'Patients ID: {self.pobj.pid}\nName: {self.pobj.pname}\nAge: {self.pobj.page}\nPhone no.: {self.pobj.pphn}'
  def allDoctors(self):
    print (f'All doctors:\nNumber of Doctors: {self.dctr}\n{self.d}')
  def allPatients(self):
    print(f'All patients:\nNumber of patiens: {self.rugi}\n{self.p}  ')


class Doctor:
  def __init__ (self,did,occupation,dname,dtype):
    self.did=did
    self.occupation=occupation
    self.dname=dname
    self.dtype=dtype
class Patient:
  def __init__ (self,pid, poccupation,pname,page,pphn):
    self.pid=pid
    self.poccupation=poccupation
    self.pname=pname
    self.page=page
    self.pphn=pphn

h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
h.allDoctors()
h.allPatients()
# Out:
# ...
# Doctors ID: 1d
# Name: Samar Kumar
# Speciality: Neurologist
# ...
# Patients ID: 1p
# Name: Kashem Ahmed
# Age: 35
# Phone no.: 12345
# ...
# Patients ID: 2p
# Name: Tanina Haque
# Age: 26
# Phone no.: 33456
# ...
# All doctors:
# Number of Doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All patients:
# Number of patiens: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}

# %%
class Vaccine:
   def __init__ (self, vnam, mdin, intrvl):
      self.vnam=vnam 
      self.mdin=mdin 
      self.intrvl=intrvl 
class Person: 
   def __init__ (self, pnam,age,ptype='General citizen'):
      self.pnam=pnam
      self.age=age 
      self.ptype=ptype 
      self.vac=None 
      self.fdose=False 
      self.sdose=False 
   def pushVaccine(self,obj,dn='1st dose'): 
      self.dn=dn 
      if self.dn=='1st dose': 
        if self.age>=25 or self.ptype=='Student': 
          print(f'1st dose done for {self.pnam}') 
          self.obj=obj 
          self.fdose=True 
        else: 
          print(f'Sorry {self.pnam} Minimum age for taking vaccines is 25 years now.')
      else:
        if self.obj.vnam!=obj.vnam:
          print(f'Sorry {self.pnam}, you can’t take 2 different vaccines')
        else:
          self.sdose=True
          print(f'2nd dose done for {self.pnam}')
   def showDetail(self):
      print(f'Name: {self.pnam} Age: {self.age} Type: {self.ptype}\nVaccine name: {self.obj.vnam}')
      if self.fdose==True and self.sdose==False:
        print(f'1st dose: given\n2nd dose: please come after {self.obj.intrvl} days')
      else:
        print(f'1st dose : given\n2nd dose: given')


astra = Vaccine("AstraZeneca", "UK", 60)
modr = Vaccine("Moderna", "UK", 30)
sin = Vaccine("Sinopharm", "China", 30)
p1 = Person("Bob", 21, "Student")
print("=================================")
p1.pushVaccine(astra)
print("=================================")
p1.showDetail()
print("=================================")
p1.pushVaccine(sin, "2nd Dose")
print("=================================")
p1.pushVaccine(astra, "2nd Dose")
print("=================================")
p1.showDetail()
print("=================================")
p2 = Person("Carol", 23, "Actor")
print("=================================")
p2.pushVaccine(sin)
print("=================================")
p3 = Person("David", 34)
print("=================================")
p3.pushVaccine(modr)
print("=================================")
p3.showDetail()
print("=================================")
p3.pushVaccine(modr, "2nd Dose")
# Out:
# ...
# 1st dose done for Bob
# ...
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: given
# 2nd dose: please come after 60 days
# ...
# Sorry Bob, you can’t take 2 different vaccines
# ...
# 2nd dose done for Bob
# ...
# Name: Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose : given
# 2nd dose: given
# ...
# Sorry Carol Minimum age for taking vaccines is 25 years now.
# ...
# 1st dose done for David
# ...
# Name: David Age: 34 Type: General citizen
# Vaccine name: Moderna
# 1st dose: given
# 2nd dose: please come after 30 days
# ...
# 2nd dose done for David

# %%
#ager mid er prosno
class Team:
  def __init__ (self,tim,world_cup,language='Spanish'):
    self.tim=tim
    self.world_cup=world_cup
    self.language=language
    self.player_list='No players assigned yet'
    self.forward=[]
    self.defender=[]
    self.cost=0
  def addPlayer(self,obj):
    self.obj=obj
    if type(self.player_list)!=list:
        self.player_list=[]
    self.player_list.append(tuple([obj.pname,obj.ptype]))
    if self.obj.ptype=='Forward':
      self.cost+=500
      self.forward.append(self.obj.pname)
    elif self.obj.ptype=='Defender':
      self.cost+=450
      self.defender.append(self.obj.pname)

  def calculateCost(self):
    if self.cost==0:
      print('No cost yet as there is no players')
    else:
      print('Total Cost:',self.cost)
  def printDetail(self):
    print(f'Team Name: {self.tim}\nWorld Cup Win: {self.world_cup}\nLanguage: {self.language} ')
    if self.forward==[] or self.defender==[]:
      pass
    else:
      print(f'Forwards:')
      for i in self.forward:
        print(i)
      print('Defenders:')
      for j in self.defender:
        print(j)

class Player:
  def __init__(self,pname,ptype='Forward'):
    self.pname=pname
    self.ptype=ptype









argentina = Team("Argentina", 2)
print("1.============================================")
print(argentina.player_list)
print("2.============================================")
argentina.calculateCost()
print("3.============================================")
argentina.printDetail()
print("4.============================================")
messi = Player("Messi")
maria = Player("Maria")
marcos = Player("Marcos", "Defender")
argentina.addPlayer(messi)
argentina.addPlayer(maria)
argentina.addPlayer(marcos)
print("5.============================================")
argentina.calculateCost()
print("6.============================================")
argentina.printDetail()
print("7.============================================")
print(argentina.player_list)
print("8.###############################################")
brazil = Team("Brazil", 5, "Portuguese")
print("9.============================================")
print(brazil.player_list)
print("10.============================================")
brazil.calculateCost()
print("11.============================================")
brazil.printDetail()
print("12.============================================")
silva = Player("Silva", "Defender")
neymar = Player("Neymar")
brazil.addPlayer(silva)
brazil.addPlayer(neymar)
print("13.============================================")
brazil.calculateCost()
print("14.============================================")
brazil.printDetail()
print("15.============================================")
print(brazil.player_list)
# Out:
# 1.============================================
# No players assigned yet
# 2.============================================
# No cost yet as there is no players
# 3.============================================
# Team Name: Argentina
# World Cup Win: 2
# Language: Spanish
# 4.============================================
# 5.============================================
# Total Cost: 1450
# 6.============================================
# Team Name: Argentina
# World Cup Win: 2
# Language: Spanish
# Forwards:
# Messi
# Maria
# Defenders:
# Marcos
# 7.============================================
# [('Messi', 'Forward'), ('Maria', 'Forward'), ('Marcos', 'Defender')]
# 8.###############################################
# 9.============================================
# No players assigned yet
# 10.============================================
# No cost yet as there is no players
# 11.============================================
# Team Name: Brazil
# World Cup Win: 5
# Language: Portuguese
# ...
